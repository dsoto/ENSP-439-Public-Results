# %% [markdown]
# (I would like to put this into a neat table for next results)
# Common Household Appliance wattages:
#
# 100 W Incandescent Lightbulb 100W
# LED Lightbulb 8W
# Table Fan 17W
# Home Air Conditioner 2500W
# Fridge/Freezer 225W
# Water Filter and Cooler 85W
# Tabel Fan 17W
# Smart Phone Charger 5W
# Clock Radio 2W
# Ceiling Fan 50W

# %%
import pandas as pd
data = pd.read_csv('aggregated_PV_data.csv', parse_dates=True, index_col=0)
data.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-e6b6493ca801> in <module>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('aggregated_PV_data.csv', parse_dates=True, index_col=0)
#       3 data.head()
#
# ...

# %%
# %matplotlib notebook
data['201'].plot()
data['202'].plot()
data['204'].plot()
data['221'].plot()
data['222'].plot()
data['223'].plot()
data['224'].plot()
data['231'].plot()
data['232'].plot()
data['233'].plot()
data['234'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9e51bad45fe5> in <module>()
#       1 get_ipython().magic(u'matplotlib notebook')
# ----> 2 data['201'].plot()
#       3 data['202'].plot()
#       4 data['204'].plot()
#       5 data['221'].plot()
#
# /projects/sage/sage-7.5/local/lib/python2.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /projects/sage/sage-7.5/local/lib/python2.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
# ...

# %% [markdown]
# # House 201

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000201.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 202

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000202.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 203

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000203.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 204

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000204.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 221

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000221.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 222

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000222.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 223

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000223.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 224

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000224.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 231

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000231.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 232

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000232.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 233

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000233.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # House 234

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv ('Household Data/EVI0000234.csv', parse_dates=True, index_col=1)
data['VALUE'].plot()
# Out:
# <img src="data:image/png;base64,...">

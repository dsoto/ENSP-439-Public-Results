# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# # Significant Blackout Standards
# 1 hour and up, note uniformity among sets and duration.
# Omit any sig blackouts isolated during evenings
# Set boundries based on time and date, not timestamps
#
# # Minor Blackouts
# 1 hour and under, minumum of 5 residences lining up

# %% [markdown]
# # Yearly Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data[:].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # finding blackouts an hour plus and recording duration and number or residences that blackout at sme time

# %% [markdown]
# # January aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data[:2937].plot(legend = False,figsize=(30, 8))

# %%
#zooming in on late January
#1/28-1/31
#00:00-24:00
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-01-28 00:00:00':'2016-02-01 00:00:00'].plot(legend = False,figsize=(30, 6))

# %%
# zooming in on January 28th, 12:00-24:00
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-01-28 13:00:00':'2016-01-28 17:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # 1 January blackout on 28th 13:15-16:15, misses 11 residences
# #frequent gaps hour or less, none across all sets

# %% [markdown]
# # Febuary aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-02-01 00:00:00':'2016-03-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %%
# Feb 6th
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-02-06 08:00:00':'2016-02-06 11:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # 2 blackouts on 6th
# # 8:30-9:30, skipps 14 residences
# # 10:00-11:00,skipps 11 residences

# %%
# F 7th
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-02-07 08:30:00':'2016-02-07 9:30:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # 1 blackout Jan 7th
# # 8:45 -9:45, misses 5 residences

# %% [markdown]
# # March Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-03-01 00:00:00':'2016-04-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-03-20 20:00:00':'2016-03-21 06:00:00'].plot(legend = False,figsize=(16, 8))

# %% [markdown]
# # 1 blackout March 20th-21st
# # 21:15-4:15, 15 residents ommited
# # all but 3 cut out at least once for 30-15 minutes during that 7 hour period

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-03-25 18:00:00':'2016-03-25 21:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # April Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-04-01 00:00:00':'2016-05-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # May Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-05-01 00:00:00':'2016-06-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # June  Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-06-01 00:00:00':'2016-07-01 00:00:00'].plot(legend = False,figsize=(16, 8))

# %% [markdown]
# # July Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-07-01 00:00:00':'2016-08-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # August Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-08-01 00:00:00':'2016-09-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # September Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-09-01 00:00:00':'2016-10-01 00:00:00'].plot(legend = False,figsize=(30, 8))

# %% [markdown]
# # major earthquake sept 16th and 17th w/o sig blackout to match
# insets photo of Jayapura epicienter

# %% [markdown]
# # October Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-10-01 00:00:00':'2016-11-01 00:00:00'].plot(legend = False,figsize=(16, 8))

# %% [markdown]
# # November Aggregated

# %%
data = pd.read_csv('../Data/aggregated_PV_data.csv', parse_dates = True, index_col = 0)
#data.head()
columns = ['141','202','152','152','153','154','161','162','163','114','124','133','143','151','164','174','194','204','223','224','234']
data = data.drop(columns, 1)
data['2016-11-01 00:00:00':'2016-12-01 00:00:00'].plot(legend = False,figsize=(30, 8))

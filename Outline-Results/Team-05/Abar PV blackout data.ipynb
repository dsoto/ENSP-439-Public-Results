# %%
#Abar Residences
import pandas as pd
data_111 = pd.read_csv('../Data/EVI0000111.csv', parse_dates = True, index_col = 1)
data_112 = pd.read_csv('../Data/EVI0000112.csv', parse_dates = True, index_col = 1)
data_113 = pd.read_csv('../Data/EVI0000113.csv', parse_dates = True, index_col = 1)
data_114 = pd.read_csv('../Data/EVI0000114.csv', parse_dates = True, index_col = 1)
data_121 = pd.read_csv('../Data/EVI0000121.csv', parse_dates = True, index_col = 1)
data_122 = pd.read_csv('../Data/EVI0000122.csv', parse_dates = True, index_col = 1)
data_123 = pd.read_csv('../Data/EVI0000123.csv', parse_dates = True, index_col = 1)
data_124 = pd.read_csv('../Data/EVI0000124.csv', parse_dates = True, index_col = 1)
data_131 = pd.read_csv('../Data/EVI0000131.csv', parse_dates = True, index_col = 1)
data_132 = pd.read_csv('../Data/EVI0000132.csv', parse_dates = True, index_col = 1)
data_133 = pd.read_csv('../Data/EVI0000133.csv', parse_dates = True, index_col = 1)
data_134 = pd.read_csv('../Data/EVI0000134.csv', parse_dates = True, index_col = 1)
data_141 = pd.read_csv('../Data/EVI0000141.csv', parse_dates = True, index_col = 1)
data_142 = pd.read_csv('../Data/EVI0000142.csv', parse_dates = True, index_col = 1)
data_143 = pd.read_csv('../Data/EVI0000143.csv', parse_dates = True, index_col = 1)
data_144 = pd.read_csv('../Data/EVI0000144.csv', parse_dates = True, index_col = 1)
data_151 = pd.read_csv('../Data/EVI0000151.csv', parse_dates = True, index_col = 1)
data_152 = pd.read_csv('../Data/EVI0000152.csv', parse_dates = True, index_col = 1)
data_153 = pd.read_csv('../Data/EVI0000153.csv', parse_dates = True, index_col = 1)
data_154 = pd.read_csv('../Data/EVI0000154.csv', parse_dates = True, index_col = 1)
data_161 = pd.read_csv('../Data/EVI0000161.csv', parse_dates = True, index_col = 1)
data_162 = pd.read_csv('../Data/EVI0000162.csv', parse_dates = True, index_col = 1)
data_163 = pd.read_csv('../Data/EVI0000163.csv', parse_dates = True, index_col = 1)
data_164 = pd.read_csv('../Data/EVI0000164.csv', parse_dates = True, index_col = 1)
data_171 = pd.read_csv('../Data/EVI0000171.csv', parse_dates = True, index_col = 1)
data_172 = pd.read_csv('../Data/EVI0000172.csv', parse_dates = True, index_col = 1)
data_173 = pd.read_csv('../Data/EVI0000173.csv', parse_dates = True, index_col = 1)
data_174 = pd.read_csv('../Data/EVI0000174.csv', parse_dates = True, index_col = 1)
data_181 = pd.read_csv('../Data/EVI0000181.csv', parse_dates = True, index_col = 1)
data_182 = pd.read_csv('../Data/EVI0000182.csv', parse_dates = True, index_col = 1)
data_183 = pd.read_csv('../Data/EVI0000183.csv', parse_dates = True, index_col = 1)
data_184 = pd.read_csv('../Data/EVI0000184.csv', parse_dates = True, index_col = 1)
data_191 = pd.read_csv('../Data/EVI0000191.csv', parse_dates = True, index_col = 1)
data_192 = pd.read_csv('../Data/EVI0000192.csv', parse_dates = True, index_col = 1)
data_193 = pd.read_csv('../Data/EVI0000193.csv', parse_dates = True, index_col = 1)
data_194 = pd.read_csv('../Data/EVI0000194.csv', parse_dates = True, index_col = 1)
data_201 = pd.read_csv('../Data/EVI0000201.csv', parse_dates = True, index_col = 1)
data_202 = pd.read_csv('../Data/EVI0000202.csv', parse_dates = True, index_col = 1)
data_203 = pd.read_csv('../Data/EVI0000203.csv', parse_dates = True, index_col = 1)
data_204 = pd.read_csv('../Data/EVI0000204.csv', parse_dates = True, index_col = 1)
data_221 = pd.read_csv('../Data/EVI0000221.csv', parse_dates = True, index_col = 1)
data_222 = pd.read_csv('../Data/EVI0000222.csv', parse_dates = True, index_col = 1)
data_223 = pd.read_csv('../Data/EVI0000223.csv', parse_dates = True, index_col = 1)
data_224 = pd.read_csv('../Data/EVI0000224.csv', parse_dates = True, index_col = 1)
data_231 = pd.read_csv('../Data/EVI0000231.csv', parse_dates = True, index_col = 1)
data_232 = pd.read_csv('../Data/EVI0000232.csv', parse_dates = True, index_col = 1)
data_234 = pd.read_csv('../Data/EVI0000234.csv', parse_dates = True, index_col = 1)

# %%
#Residential data 
# %matplotlib inline
data_111['VALUE'].plot()
data_112['VALUE'].plot()
data_113['VALUE'].plot()
data_121['VALUE'].plot()
data_122['VALUE'].plot()
data_123['VALUE'].plot()
data_131['VALUE'].plot()
data_132['VALUE'].plot()
data_134['VALUE'].plot()
data_141['VALUE'].plot()
data_142['VALUE'].plot()
data_144['VALUE'].plot()
data_171['VALUE'].plot()
data_172['VALUE'].plot()
data_173['VALUE'].plot()
data_181['VALUE'].plot()
data_182['VALUE'].plot()
data_183['VALUE'].plot()
data_184['VALUE'].plot()
data_191['VALUE'].plot()
data_192['VALUE'].plot()
data_202['VALUE'].plot()

# %%
# abnormal residential sets, 
# %matplotlib inline
data_152['VALUE'].plot()#zeroes out from 209.484 on 6/9 @ 12:00:57-15:00, meeter reset 
data_153['VALUE'].plot()#zeroes out from 213.941 on 6/9 @ 12:00:57-13:15, meter reset
data_154['VALUE'].plot()#zeroes out from 16.48 on 6/9 @ 12:00:57- 11/17 @ 10:15
data_161['VALUE'].plot()#bounces between 12.46 and 34.186 each 15 min incremant on 6/7 @11:00-15:00), brownout 
data_162['VALUE'].plot()#bounces between 13.041 and 33.295 on 6/7 @11:30-15:00, brown out 
data_163['VALUE'].plot()#bounces between 78.135 and 17.759 and 6/7 @11:30-15:00, brownout

# %%
#non-residentials
# %matplotlib inline
data_114['VALUE'].plot()
data_124['VALUE'].plot()
data_133['VALUE'].plot()
data_143['VALUE'].plot()
data_151['VALUE'].plot()
data_164['VALUE'].plot()
data_174['VALUE'].plot()
data_194['VALUE'].plot()
data_204['VALUE'].plot()
data_223['VALUE'].plot()
data_224['VALUE'].plot()
data_234['VALUE'].plot()

# %% [markdown]
# #Non omited residences Slope as a funcion of date

# %%
# %matplotlib inline
df=data_111['VALUE']
data_111['VALUE'].diff(1).plot()

# %%
data_112['VALUE'].diff(1).plot()

# %%
data_113['VALUE'].diff(1).plot()

# %%
data_121['VALUE'].diff(1).plot()

# %%
data_122['VALUE'].diff(1).plot()

# %%
df=data_122['VALUE']
df[:100].diff().plot()

# %%
data_123['VALUE'].diff(1).plot()

# %%
data_131['VALUE'].diff(1).plot()

# %%
data_132['VALUE'].diff(1).plot()

# %%
data_134['VALUE'].diff(1).plot()

# %%
data_141['VALUE'].diff(1).plot()

# %%
data_142['VALUE'].diff(1).plot()

# %%
data_144['VALUE'].diff(1).plot()

# %%
data_171['VALUE'].diff(1).plot()

# %%
data_172['VALUE'].diff(1).plot()

# %%
data_173['VALUE'].diff(1).plot()

# %%
data_181['VALUE'].diff(1).plot()

# %%
data_182['VALUE'].diff(1).plot()

# %%
data_184['VALUE'].diff(1).plot()

# %%
data_191['VALUE'].diff(1).plot()

# %%
data_192['VALUE'].diff(1).plot()

# %% [markdown]
# To begin with our notebook, we would like to start by importing data from the buildings GMC, Ives, Salazar and Schulz. Then, we will create a graph and interpret each one.

# %% [markdown]
# # GMC

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv('GMC.csv', parse_dates=True, index_col=0)
data['Demand (kW)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [raw]
# Interpretation: What causes the energy to drop so drastically?
# Possible metering error?
# Was there an event that night in the GMC?

# %% [markdown]
# # IVES

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv('Ives.csv', parse_dates=True, index_col=0)
data['Demand(kW)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Interpretation: Electricity consumption over a 24 hour period of Ives Hall.

# %% [markdown]
# # SALAZAR

# %% [markdown]
# Interpretation: What causes the spikes in data?  Why do both Salazar and Schultz drop between the hours of 9am-12pm (peak student rush times)?

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv('salazar.csv', parse_dates=True, index_col=0)
data['Demand'].plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-73eb7a37e65f> in <module>()
#       1 import pandas as pd
#       2 data = pd.read_csv('salazar.csv', parse_dates=True, index_col=0)
# ----> 3 mean['Demand']
#
# NameError: name 'mean' is not defined

# %% [markdown]
# # SCHULZ

# %%
# %matplotlib notebook
import pandas as pd
data = pd.read_csv('Schulz1.csv', parse_dates=True, index_col=0)
data['Demand(kW)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

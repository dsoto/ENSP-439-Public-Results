# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ajau = pd.read_csv("../diesel_data/ajau.csv")
atamali = pd.read_csv("../diesel_data/atamali.csv")
asei = pd.read_csv("../diesel_data/asei.csv")
ayapo = pd.read_csv("../diesel_data/ayapo.csv")

# %%
ajau["kWh export"].plot()
atamali["kWh export"].plot()
asei["kWh export"].plot()
ayapo["kWh export"].plot()

# %%
# %matplotlib inline
ajau["kWh export"].diff(1).plot()

# %%
# %matplotlib inline
atamali["kWh export"].diff(1).plot()

# %%
# %matplotlib inline
asei["kWh export"].diff(1).plot()

# %%
# %matplotlib inline
ayapo["kWh export"].diff(1).plot()
